# %% [markdown]
# <h2 align="center">GEO2010 Spring 2017</h2>
#
#
# <h3 align = "center" > Exercise 2 </h3>
#
# #### Date: 2017/01/30
#
# The obligatory exercise must be handed in before February 15th at 14:15.

# %% [markdown]
# **Training exercise 1**

# %% [markdown]
# Objectives:
#
# a) to become familiar with basic aspects of hydrologic data
#
# b) to become familiar with some basic statistical concept.
#
#
# **Background:**
#
# There are thousands of station across the country where precipitation and streamflow are recorded.
# Some of these stations have been in operation for over 100 years and they record data at frequent intervals (eg.every 15 minutes). As you might expect, vast amounts of hydrologic data available and these data can be used fro a variety of purposes.
#
#
# **DATA:** You should receive an csv file with two tables of data, one listing the average annual discharge of the River A, the other listing annual precipitation. Please use these data sets  to answer the following questions:

# %% [markdown]
# 1. Derive the conversion factor to convert values of discharge from cubic feet per second (cfs) to cubic meter per second (cms)
# 2. Enter a formula in the column adjacent to discharge data, converting value from cfs to cms.
# 3. Calculate the mean, variance, standard deviation and coefficient of variation of all the average annual streamflows.
# 4. plot a histogram (frequency histogram) of the discharge value and precipitation. Compare the two histogram of average annual discharge and average annual precipitation. How are the histogram different?
# 5. prepare a table with mean, standard deviation, variation and coefficient of variation for both data sets (Average annual discharge in unit of cms and Total precipitation in  unit of mm) and write a couple of sentences on your calculation.

# %% [markdown]
# #### example table
# |stats|discharge|precipitation|
# |--|-----------|
# |mean |--|--|
# |stand |--|--|
# |cv|--|--|

# %% [markdown]
# **Training exercise 2**
#
# a) The water flux away from the atmosphere P, (global precipitation) during one year is 576700 km3/year. Calculate the value with the unit mm/year. [Given: Area of sphere = 4Πr2    where, r = 6300 KM]
#
# b) Specific discharge, q, is the discharge, Q, divided by the catchment area, A. Which two units are common to use for the specific discharge?
#
# c) The catchment area of Connecticut river is 20370 km2 and the yearly discharge is 386 m3/s. What is the yearly specific discharge in this catchment?

# %% [markdown]
# **Training exercise 3 - Reference Dingman, page no 28**
#
# Residence time (or turn-over time or average transit time) is the average time a water particle spends in a storage. Calculate the residence times for all the global storages in figure 3.16. Use the formula
#
# Tr = S/mQ= S/mI
#
# where Tr is residence time, S is the average storage volume, mQ is the average outflow and mI is the average inflow.

# %%
from IPython.display import Image
Image(filename='res_time.png') #

# %% [markdown]
# The units here are: km3 for the storages and km3/year for the fluxes.

# %% [markdown]
# **Training exercise 4**
#
# Explain figure 2.22 Dingman.

# %%
Image(filename='evop.png')

# %% [markdown]
# **Obligatory exercise 2 – Conversions of units (Reference : 1Dingman84.pdf)**
#
#
#
# a) Discharge is usually measured with the unit m3/s [V/T]. Mean daily discharge is calculated by taking the average of all the measured discharges during a day. In which unit is mean daily discharge given? Mean monthly discharge is calculated by taking the average of all the measured discharges during a given month. In which unit is mean monthly discharge given?
#
#
# b) In the water balance equation (eq. 1.15 in Dingman), we are not interested in discharge with the unit m3/s [L3/T] because precipitation and evapotranspiration are given in the unit mm/time [L/T]. The discharge, Q, is therefore converted to runoff (or specific discharge), q, by dividing Q by the catchment area, A.
#
# q [L/T]= Q [L3/T] / A [L2]
#
# The catchment area of Vikka is 4.6 km2 and the yearly discharge is 0.098 m3/s (i.e. average discharge of one year). What is the yearly specific discharge in this catchment, in mm/s? what is it in mm/year?
#
#
# c) Precipitation measurements are sometimes given in the unit kg/(m2·s).
# Convert 2.5·10-5 kg/(m2·s) to mm/s, and then to mm/year.
